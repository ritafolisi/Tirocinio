# %%
import fuzzy_c_iris as fc

# %%
import copy
import math
import random
import time
import sys
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import decimal
# Out:
# <module 'fuzzy_c_iris' from '/home/alessia/Tirocinio/Fuzzy-C-master/fuzzy_c_iris.py'>

# %%
data, cluster_location = fc..import_data_format_iris("iris.csv")
fc.print_matrix(data)
# Out:
# finished importing data
# [5.1, 3.5, 1.4, 0.2]
# [4.9, 3.0, 1.4, 0.2]
# [4.7, 3.2, 1.3, 0.2]
# [4.6, 3.1, 1.5, 0.2]
# [5.0, 3.6, 1.4, 0.2]
# [5.4, 3.9, 1.7, 0.4]
# [4.6, 3.4, 1.4, 0.3]
# [5.0, 3.4, 1.5, 0.2]
# [4.4, 2.9, 1.4, 0.2]
# [4.9, 3.1, 1.5, 0.1]
# [5.4, 3.7, 1.5, 0.2]
# [4.8, 3.4, 1.6, 0.2]
# [4.8, 3.0, 1.4, 0.1]
# [4.3, 3.0, 1.1, 0.1]
# [5.8, 4.0, 1.2, 0.2]
# [5.7, 4.4, 1.5, 0.4]
# [5.4, 3.9, 1.3, 0.4]
# [5.1, 3.5, 1.4, 0.3]
# [5.7, 3.8, 1.7, 0.3]
# [5.1, 3.8, 1.5, 0.3]
# [5.4, 3.4, 1.7, 0.2]
# [5.1, 3.7, 1.5, 0.4]
# [4.6, 3.6, 1.0, 0.2]
# [5.1, 3.3, 1.7, 0.5]
# [4.8, 3.4, 1.9, 0.2]
# [5.0, 3.0, 1.6, 0.2]
# [5.0, 3.4, 1.6, 0.4]
# [5.2, 3.5, 1.5, 0.2]
# [5.2, 3.4, 1.4, 0.2]
# [4.7, 3.2, 1.6, 0.2]
# [4.8, 3.1, 1.6, 0.2]
# [5.4, 3.4, 1.5, 0.4]
# [5.2, 4.1, 1.5, 0.1]
# [5.5, 4.2, 1.4, 0.2]
# [4.9, 3.1, 1.5, 0.1]
# [5.0, 3.2, 1.2, 0.2]
# [5.5, 3.5, 1.3, 0.2]
# [4.9, 3.1, 1.5, 0.1]
# [4.4, 3.0, 1.3, 0.2]
# [5.1, 3.4, 1.5, 0.2]
# [5.0, 3.5, 1.3, 0.3]
# [4.5, 2.3, 1.3, 0.3]
# ...

# %%
start = time.time()

final_location = fc.fuzzy(data , 2 , 2)

accuracy = fc.checker_iris(final_location)
accuracy = accuracy.split(" ")[0]
#usa Decimal (from decimal import Decimal e poi Decimal(x)) se vuoi più di 15 cifre significative
accuracy = float(accuracy)
print(accuracy)
# Out:
# finished clustering
# normalised U
# 50.0
# 97.0
# 147.0
# 98.0

# %%
fc.train("iris.csv")
# Out:
# finished importing data
# finished clustering
# normalised U
# 32.0
# 64.0
# 97.0
# 64.66666666666666
